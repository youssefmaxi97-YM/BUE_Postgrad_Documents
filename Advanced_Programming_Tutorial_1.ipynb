# %% [markdown]
# <a href="https://colab.research.google.com/github/youssefmaxi97-YM/BUE_Postgrad_Documents/blob/main/Advanced_Programming_Tutorial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Hello world
this is a function for ....
"""


print("Hello world ")
# Out:
# Hello world

# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
x = 7

# %%
print(x)
# Out:
# 7

# %%
y = "youssef"

# %%
print(y)
# Out:
# youssef

# %%
welcomeMessage = "hello user welcome to our site"

# %%
print(welcomeMessage)
# Out:
# hello user welcome to our site

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(welcomeMessage))
# Out:
# <class 'str'>

# %%
z = 5.7
print(type(z))
# Out:
# <class 'float'>

# %%
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-fa0134f942c4> in <cell line: 1>()
# ----> 1 print(X)
#
# NameError: name 'X' is not defined

# %%
#Camel Case
myVariableName = "youssef"

#snake Case
my_variable_name = "youssef"

# %%
x, y, z = "orange", "banana", 8

# %%
print(x)
# Out:
# orange

# %%
print(y)
# Out:
# banana

# %%
print(z)
# Out:
# 8

# %%
print(x +y +z)
# Out:
# orangebanana

# %%
str()
int()
float()
list()
dict()
tuple()
set()
bool()

# %%
x = int(input("enter your age"))

print("enter your age" , x)
# Out:
# enter your ageyoussef
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-5906a1a7d340> in <cell line: 1>()
# ----> 1 x = int(input("enter your age"))
#       2
#       3 print("enter your age" , x)
#
# ValueError: invalid literal for int() with base 10: 'youssef'

# %%
message = "hello world welcome to pythonw world"
# Out:
# False

# %%
r = float(input("enter radius"))

area = 3.14 * r * r
print(area)
# Out:
# enter radius5
# 78.5
